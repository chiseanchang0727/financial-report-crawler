# %%
import pandas as pd
import yfinance as yf

# %%
ticker_symbol = 'AAPL'

aapl = yf.Ticker(ticker_symbol)

historical_data = aapl.history(period='1Y')

# %%
financials = aapl.financials

# %%
aapl.income_stmt
# Out:
#                                                         2023-09-30  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                           0.147
# Normalized EBITDA                                   129188000000.0
# Net Income From Continuing Operation Net Minori...   96995000000.0
# Reconciled Depreciation                              11519000000.0
# Reconciled Cost Of Revenue                          214137000000.0
# EBITDA                                              129188000000.0
# EBIT                                                117669000000.0
# Net Interest Income                                   -183000000.0
# Interest Expense                                      3933000000.0
# Interest Income                                       3750000000.0
# Normalized Income                                    96995000000.0
# Net Income From Continuing And Discontinued Ope...   96995000000.0
# ...

# %%
aapl.get_income_stmt()
# Out:
#                                                         2023-09-30  \
# TaxEffectOfUnusualItems                                        0.0
# TaxRateForCalcs                                              0.147
# NormalizedEBITDA                                    129188000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   96995000000.0
# ReconciledDepreciation                               11519000000.0
# ReconciledCostOfRevenue                             214137000000.0
# EBITDA                                              129188000000.0
# EBIT                                                117669000000.0
# NetInterestIncome                                     -183000000.0
# InterestExpense                                       3933000000.0
# InterestIncome                                        3750000000.0
# NormalizedIncome                                     96995000000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      96995000000.0
# ...

# %%
aapl.cashflow
# Out:
#                                                     2023-09-30  \
# Free Cash Flow                                   99584000000.0
# Repurchase Of Capital Stock                     -77550000000.0
# Repayment Of Debt                               -11151000000.0
# Issuance Of Debt                                  5228000000.0
# Issuance Of Capital Stock                                  NaN
# Capital Expenditure                             -10959000000.0
# Interest Paid Supplemental Data                   3803000000.0
# Income Tax Paid Supplemental Data                18679000000.0
# End Cash Position                                30737000000.0
# Beginning Cash Position                          24977000000.0
# Changes In Cash                                   5760000000.0
# Financing Cash Flow                            -108488000000.0
# Cash Flow From Continuing Financing Activities -108488000000.0
# Net Other Financing Charges                      -6012000000.0
# ...

# %%
aapl.recommendations_summary
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m         11   21     6     0           0
# 1    -1m         12   23    10     1           0
# 2    -2m         12   21    10     1           0
# 3    -3m         10   24     7     1           0

# %%
aapl.upgrades_downgrades
# Out:
#                                     Firm         ToGrade   FromGrade Action
# GradeDate
# 2024-09-25 14:27:12  New Street Research         Neutral     Neutral   reit
# 2024-09-24 09:42:31              Needham             Buy         Buy   reit
# 2024-09-19 10:41:39              Needham             Buy         Buy   reit
# 2024-09-16 16:00:10   Evercore ISI Group      Outperform  Outperform   reit
# 2024-09-10 15:48:17            JP Morgan      Overweight  Overweight   main
# ...                                  ...             ...         ...    ...
# 2014-09-30 10:00:21            Jefferies            Hold               init
# 2014-09-10 13:00:00             Barclays      Overweight               main
# 2014-09-10 12:00:00          Wells Fargo  Market Perform               main
# 2014-09-10 09:59:13        Goldman Sachs             Buy               main
# 2012-09-12 11:51:00        Hudson Square             Buy               main
#
# [970 rows x 4 columns]

# %%
aapl.earnings_estimate
# Out:
#      numberOfAnalysts   avg   low  high  yearAgoEps  growth
# 0q                 26  1.60  1.53  1.65        1.36   0.176
# +1q                20  2.39  2.21  2.61        2.18   0.096
# 0y                 41  6.70  6.57  6.76        5.73   0.169
# +1y                41  7.48  6.88  8.00        6.70   0.116

# %%
aapl.revenue_estimate
# Out:
#      numberOfAnalysts           avg           low          high  \
# 0q                 25   94410100000   93653000000   97945300000
# +1q                19  128424000000  123883000000  133406000000
# 0y                 39  390372000000  387118000000  394050000000
# +1y                39  421688000000  401691000000  441882000000
#
#      yearAgoRevenue  growth
# 0q      83600100000   0.129
# +1q    111695000000   0.150
# 0y     358027000000   0.090
# +1y    390372000000   0.080

# %%
aapl.eps_trend
# Out:
#      current  7daysAgo  30daysAgo  60daysAgo  90daysAgo
# 0q      1.60      1.60       1.59       1.55       1.54
# +1q     2.39      2.39       2.39       2.38       2.34
# 0y      6.70      6.70       6.70       6.61       6.59
# +1y     7.48      7.48       7.48       7.34       7.29

# %%
aapl.earnings_history
# Out:
#             epsEstimate  epsActual  epsDifference  surprisePercent
# 2023-09-30         1.30       1.36           0.06            0.046
# 2023-12-31         2.10       2.18           0.08            0.038
# 2024-03-31         1.50       1.53           0.03            0.020
# 2024-06-30         1.35       1.40           0.05            0.037

# %%
aapl.earnings_dates
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2025-07-30 06:00:00-04:00           NaN           NaN          NaN
# 2025-04-30 06:00:00-04:00           NaN           NaN          NaN
# 2025-01-30 16:00:00-05:00           NaN           NaN          NaN
# 2024-10-31 06:00:00-04:00          1.60           NaN          NaN
# 2024-08-01 16:00:00-04:00          1.35          1.40       0.0399
# 2024-05-02 16:00:00-04:00          1.50          1.53       0.0197
# 2024-02-01 16:00:00-05:00          2.10          2.18       0.0390
# 2023-11-02 16:00:00-04:00          1.39          1.46       0.0492
# 2023-08-03 16:00:00-04:00          1.19          1.26       0.0549
# 2023-05-04 16:00:00-04:00          1.43          1.52       0.0603
# 2023-02-02 16:00:00-05:00          1.94          1.88      -0.0288
# 2022-10-27 16:00:00-04:00          1.27          1.29       0.0155

# %%
start_date, end_date = '2017-01-01', '2024-07-31'
aapl_history = yf.download('AAPL', start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
aapl_history
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03   28.950001   29.082500   28.690001   29.037500   26.921547
# 2017-01-04   28.962500   29.127501   28.937500   29.004999   26.891415
# 2017-01-05   28.980000   29.215000   28.952499   29.152500   27.028172
# 2017-01-06   29.195000   29.540001   29.117500   29.477501   27.329493
# 2017-01-09   29.487499   29.857500   29.485001   29.747499   27.579807
# ...                ...         ...         ...         ...         ...
# 2024-07-24  224.000000  224.800003  217.130005  218.539993  218.287323
# 2024-07-25  218.929993  220.850006  214.619995  217.490005  217.238556
# 2024-07-26  218.699997  219.490005  216.009995  217.960007  217.708008
# 2024-07-29  216.960007  219.300003  215.750000  218.240005  217.987686
# 2024-07-30  219.190002  220.330002  216.119995  218.800003  218.547043
#
#                Volume
# Date
# 2017-01-03  115127600
# 2017-01-04   84472400
# 2017-01-05   88774400
# ...
