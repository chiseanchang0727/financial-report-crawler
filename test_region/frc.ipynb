# %%
import pandas as pd
import requests
from datetime import datetime
from bs4 import BeautifulSoup
from utils import read_config, MySQLAgent
import time, random

# %%
config = read_config('.env/connections.json')
sql_agent = MySQLAgent(config['VM1_mysql_conn_info'])

# %%
config['VM1_mysql_conn_info']
# Out:
# {'user': 'aiadmin',
#  'pw': 'aichat2030!',
#  'host': '138.3.214.21',
#  'port': 3306,
#  'database': 'CrawlerDB'}

# %%
query = """
select distinct company_name
from company

"""

df_company = sql_agent.read_table(query=query)
df_company
# Out:
#            company_name
# 0            國昌綜合工廠有限公司
# 1          華聯食品工業股份有限公司
# 2            建寶食品股份有限公司
# 3      財團法人台北市瑠公農業產銷基金會
# 4              新光醫療財團法人
# ...                 ...
# 11099           尚鱻農漁特產行
# 11100             容昇發商行
# 11101             豪富企業社
# 11102          華秝茶油純釀油坊
# 11103           京川食品物料行
#
# [11104 rows x 1 columns]

# %%
# df_company.to_csv('files/company_name.csv', index=False, encoding='utf-16')

# %%
query = """
select 公司代號 as stock_num, 營利事業統一編號 as busi_acc, 公司名稱 as company_name
from listed_otc_company
"""

otc = sql_agent.read_table(query=query)
otc.head()
# Out:
#   stock_num  busi_acc company_name
# 0      1101  11913502   臺灣水泥股份有限公司
# 1      1102   3244509   亞洲水泥股份有限公司
# 2      1103  11892801   嘉新水泥股份有限公司
# 3      1104   7568009   環球水泥股份有限公司
# 4      1108  40601248   幸福水泥股份有限公司

# %%
otc[otc['stock_num'] == '1101'].busi_acc[0]
# Out:
# '11913502'

# %%
query = """
select *
from mops_season_report_copy
"""

fr = sql_agent.read_table(query=query)
fr
# Out:
#                           acct_name  this_year_amt this_year_percent  \
# 0                              流動資產              0                 0
# 1                           現金及約當現金        1136975              3.98
# 2               透過損益按公允價值衡量之金融資產－流動          14619              0.05
# 3           透過其他綜合損益按公允價值衡量之金融資產－流動        2869282             10.04
# 4                  按攤銷後成本衡量之金融資產－流動         131334              0.46
# ...                             ...            ...               ...
# 32947              本期現金及約當現金增加（減少）數         283887                 0
# 32948                   期初現金及約當現金餘額        2106903                 0
# 32949                   期末現金及約當現金餘額        2390790                 0
# 32950               資產負債表帳列之現金及約當現金        1910157                 0
# 32951  分類至待出售（非流動）資產（或處分群組）之現金及約當現金         480633                 0
#
#        last_year_amt last_year_percent        report_name  company_id  \
# 0                  0                 0       BalanceSheet        1104
# 1             840325              2.99       BalanceSheet        1104
# 2              57577               0.2       BalanceSheet        1104
# 3            2392367               8.5       BalanceSheet        1104
# 4             102367              0.36       BalanceSheet        1104
# ...              ...               ...                ...         ...
# 32947         164587                 0  CashFlowStatement        9944
# 32948        1999100                 0  CashFlowStatement        9944
# 32949        2163687                 0  CashFlowStatement        9944
# 32950        2163687                 0  CashFlowStatement        9944
# 32951              0                 0  CashFlowStatement        9944
#
#       company_name creation_date  seq period_year season
# 0       環球水泥股份有限公司    2024-07-13    1         113      2
# 1       環球水泥股份有限公司    2024-07-13    2         113      2
# 2       環球水泥股份有限公司    2024-07-13    3         113      2
# 3       環球水泥股份有限公司    2024-07-13    4         113      2
# 4       環球水泥股份有限公司    2024-07-13    5         113      2
# ...            ...           ...  ...         ...    ...
# 32947   新麗企業股份有限公司    2024-07-16   60         113      2
# 32948   新麗企業股份有限公司    2024-07-16   61         113      2
# 32949   新麗企業股份有限公司    2024-07-16   62         113      2
# 32950   新麗企業股份有限公司    2024-07-16   63         113      2
# 32951   新麗企業股份有限公司    2024-07-16   64         113      2
#
# [32952 rows x 12 columns]

# %%
fr.report_name.unique()
# Out:
# array(['BalanceSheet', 'ProfitAndLose', 'CashFlowStatement'], dtype=object)

# %%
company_list = pd.read_csv('company_data.csv')
company_list.head()
# Out:
#    business_accounting_no      company_name internal_id    query_name
# 0                  700019        國昌綜合工廠有限公司       K7913        國昌綜合工廠
# 1                  713181      華聯食品工業股份有限公司       J5984          華聯食品
# 2                  784930        建寶食品股份有限公司       K4395          建寶食品
# 3                  833117          高立展業有限公司       Q0717          高立展業
# 4                  966299  財團法人台北市瑠公農業產銷基金會       K9232  台北市瑠公農業產銷基金會

# %%
# 網站連線資料
BalanceSheetURL = "https://mops.twse.com.tw/mops/web/ajax_t164sb03";      # 資產負債表
ProfitAndLoseURL = "https://mops.twse.com.tw/mops/web/ajax_t164sb04";    # 損益表
CashFlowStatementURL = "https://mops.twse.com.tw/mops/web/ajax_t164sb05"; # 現金流量表

# %%
query = """
select distinct company_name
from company
where business_accounting_no = '35412204'
"""

company_list = sql_agent.read_table(query=query)
company_list
# Out:
#   company_name
# 0   華新麗華股份有限公司

# %%
stock_list = otc[otc['company_name'].isin(set(company_list.company_name))].stock_num.unique()
print("num of stock in comapny_list:", len(stock_list))
df_frc = pd.DataFrame()
error_stock_list = []
# Out:
# num of stock in comapny_list: 1

# %%
# Balancesheet crawler
for stock_number in stock_list:
       
    # stock_number = '1231'
    year = 113
    season = 1
    url = BalanceSheetURL

    form_data = {
        'encodeURIComponent':1,
        'step':1,
        'firstin':1,
        'off':1,
        'co_id':stock_number,
        'year': year,
        'season': season,
    }
    
    try:
        r = requests.post(url,form_data)
        soup = BeautifulSoup(r.text, 'html.parser')
        table = soup.find_all('table')[1]
        headers = [header.text for header in table.find_all('th')]
        rows = []
        for row in table.find_all('tr')[1:]:
            cells = row.find_all('td')
            cells_text = [cell.text.strip() for cell in cells]
            rows.append(cells_text)

        # columns = ['acct_name', 'this_year_amt', 'this_year_percent', 'last_hf_amt', 'last_hf_amt_%', 'last_year_amt', 'last_year_percent']
        columns = ['acct_name', 'this_year_amt', 'this_year_percent', 'last_hf_amt', 'last_hf_amt_%', 'last_year_amt', 'last_year_percent', 'last_year_hf_amt', 'last_year_hf_percent']
        # Create a DataFrame
        df_temp = pd.DataFrame(rows, columns=columns)
        df_select = df_temp.iloc[:, [0,1,2,5,6]].iloc[3:].copy()
        
        df_select['report_name'] = 'BalanceSheet'
        df_select['company_id'] = otc[otc['stock_num'] == str(stock_number)].stock_num.values[0]
        df_select['company_name'] = otc[otc['stock_num'] == str(stock_number)].company_name.values[0]
        df_select['creation_date'] = datetime.now().strftime('%Y-%m-%d')
        df_select['seq'] = range(1, len(df_select) + 1)
            

        df_select['stock'] = stock_number

        df_frc = pd.concat([df_frc, df_select], axis=0)
        
        print(f'get {stock_number}')
        
        # time.sleep(random.uniform(10, 35))
         
    except requests.RequestException as e:
        error_stock_list.append(stock_number)
        print(f'Failed to retrieve data for stock number {stock_number}: {e}')
    except ValueError as e:
        error_stock_list.append(stock_number)
        print(f'Error parsing data for stock number {stock_number}: {e}')
    except Exception as e:
        error_stock_list.append(stock_number)
        print(f'An unexpected error occurred for stock number {stock_number}: {e}')
# Out:
# get 1605

# %%
df_frc_2 = df_frc.drop(['stock'], axis=1)

# %%
df_frc_2
# Out:
#                     acct_name this_year_amt this_year_percent last_year_amt  \
# 3                        流動資產
# 4                     現金及約當現金    12,313,790              4.63     8,257,051
# 5         透過損益按公允價值衡量之金融資產－流動     1,339,835              0.50       150,209
# 6            按攤銷後成本衡量之金融資產－流動           737              0.00         1,509
# 7                  避險之金融資產－流動         9,427              0.00        15,460
# ..                        ...           ...               ...           ...
# 70                      非控制權益     9,927,706              3.74    10,708,783
# 71                       權益總額   151,479,608             57.02   135,742,714
# 72                    負債及權益總計   265,675,434            100.00   255,273,437
# 73    預收股款（權益項下）之約當發行股數（單位：股）             0                               0
# 74  母公司暨子公司所持有之母公司庫藏股股數（單位：股）             0                               0
#
#    last_year_percent   report_name company_id company_name creation_date  seq
# 3                     BalanceSheet       1605   華新麗華股份有限公司    2024-07-18    1
# 4               3.23  BalanceSheet       1605   華新麗華股份有限公司    2024-07-18    2
# 5               0.06  BalanceSheet       1605   華新麗華股份有限公司    2024-07-18    3
# 6               0.00  BalanceSheet       1605   華新麗華股份有限公司    2024-07-18    4
# 7               0.01  BalanceSheet       1605   華新麗華股份有限公司    2024-07-18    5
# ..               ...           ...        ...          ...           ...  ...
# 70              4.20  BalanceSheet       1605   華新麗華股份有限公司    2024-07-18   68
# 71             53.18  BalanceSheet       1605   華新麗華股份有限公司    2024-07-18   69
# 72            100.00  BalanceSheet       1605   華新麗華股份有限公司    2024-07-18   70
# 73                    BalanceSheet       1605   華新麗華股份有限公司    2024-07-18   71
# 74                    BalanceSheet       1605   華新麗華股份有限公司    2024-07-18   72
#
# [72 rows x 10 columns]

# %%
conf = config['VM1_mysql_conn_info']
conf
# Out:
# {'user': 'aiadmin',
#  'pw': 'aichat2030!',
#  'host': '138.3.214.21',
#  'port': 3306,
#  'database': 'CrawlerDB'}

# %%
host = conf['host']
database = conf['database']
user = conf['user']
password = conf['pw']
port = conf['port']

# %%
import pandas as pd
import mysql.connector
from mysql.connector import Error

# %%
try:
    connection = mysql.connector.connect(
        host=host,
        database=database,
        user=user,
        password=password
    )
    if connection.is_connected():
        cursor = connection.cursor()
        
        for index, row in df_frc_2.iterrows():
            sql = """INSERT INTO mops_season_report_copy (acct_name, this_year_amt, this_year_percent, last_year_amt, last_year_percent, report_name, company_id, company_name, creation_date, seq)
                     VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"""
            cursor.execute(sql, tuple(row))
            connection.commit()
        
        print("Data inserted successfully")
except Error as e:
    print("Error while connecting to MySQL", e)
finally:
    if connection.is_connected():
        cursor.close()
        connection.close()
        print("MySQL connection is closed")
# Out:
# Data inserted successfully
# MySQL connection is closed

# %%
df_frc_2
# Out:
#                     acct_name this_year_amt this_year_percent last_year_amt  \
# 3                        流動資產
# 4                     現金及約當現金    12,313,790              4.63     8,257,051
# 5         透過損益按公允價值衡量之金融資產－流動     1,339,835              0.50       150,209
# 6            按攤銷後成本衡量之金融資產－流動           737              0.00         1,509
# 7                  避險之金融資產－流動         9,427              0.00        15,460
# ..                        ...           ...               ...           ...
# 70                      非控制權益     9,927,706              3.74    10,708,783
# 71                       權益總額   151,479,608             57.02   135,742,714
# 72                    負債及權益總計   265,675,434            100.00   255,273,437
# 73    預收股款（權益項下）之約當發行股數（單位：股）             0                               0
# 74  母公司暨子公司所持有之母公司庫藏股股數（單位：股）             0                               0
#
#    last_year_percent   report_name company_id company_name creation_date  seq
# 3                     BalanceSheet       1605   華新麗華股份有限公司    2024-07-18    1
# 4               3.23  BalanceSheet       1605   華新麗華股份有限公司    2024-07-18    2
# 5               0.06  BalanceSheet       1605   華新麗華股份有限公司    2024-07-18    3
# 6               0.00  BalanceSheet       1605   華新麗華股份有限公司    2024-07-18    4
# 7               0.01  BalanceSheet       1605   華新麗華股份有限公司    2024-07-18    5
# ..               ...           ...        ...          ...           ...  ...
# 70              4.20  BalanceSheet       1605   華新麗華股份有限公司    2024-07-18   68
# 71             53.18  BalanceSheet       1605   華新麗華股份有限公司    2024-07-18   69
# 72            100.00  BalanceSheet       1605   華新麗華股份有限公司    2024-07-18   70
# 73                    BalanceSheet       1605   華新麗華股份有限公司    2024-07-18   71
# 74                    BalanceSheet       1605   華新麗華股份有限公司    2024-07-18   72
#
# [72 rows x 10 columns]

# %%
sql_agent.write_table(data=df_frc_2, table_name='mops_season_report_copy', index=False, if_exists='append', data_type=None)

# %%
# try:
#     connection = mysql.connector.connect(
#         host=host,
#         database=database,
#         user=user,
#         password=password
#     )
#     if connection.is_connected():
#         cursor = connection.cursor()
#         table_name = 'mops_season_report_copy'

#         # Retrieve column names
#         cursor.execute(f"DESCRIBE {table_name}")
#         columns = cursor.fetchall()

#         # Generate and execute ALTER TABLE statements
#         for column in columns:
#             column_name = column[0]
#             alter_statement = f"ALTER TABLE {table_name} MODIFY {column_name} VARCHAR(255)"
#             cursor.execute(alter_statement)
#             connection.commit()
        
#         print("All columns converted to VARCHAR(255) successfully")
# except Error as e:
#     print("Error while connecting to MySQL", e)
# finally:
#     if connection.is_connected():
#         cursor.close()
#         connection.close()
#         print("MySQL connection is closed")
# Out:
# All columns converted to VARCHAR(255) successfully
# MySQL connection is closed

# %%
# df_frc.to_csv('fr_result.csv', index=False)
df_frc_balance = pd.read_csv('balance_result.csv')

# %%
df_frc_balance.nunique()
# Out:
# acct_name             156
# this_year_amt        9439
# this_year_percent    3217
# last_year_amt        9368
# last_year_percent    3278
# report_name             1
# company_id            209
# company_name          209
# creation_date           1
# seq                    94
# stock                 209
# dtype: int64

# %%
df_frc_balance = pd.concat([df_frc_balance, df_frc_2], axis=0)

# %%
df_frc_balance = df_frc_balance.drop(['stock'], axis=1)

# %%
df_frc_balance.company_id.nunique()
# Out:
# 210

# %%
df_profitloss = pd.DataFrame()

# %%
# Profit and loss
for stock_number in stock_list:
       
    # stock_number = '1231'
    year = 113
    season = 1
    url = ProfitAndLoseURL

    form_data = {
        'encodeURIComponent':1,
        'step':1,
        'firstin':1,
        'off':1,
        'co_id':stock_number,
        'year': year,
        'season': season,
    }
    
    try:
        r = requests.post(url,form_data)
        soup = BeautifulSoup(r.text, 'html.parser')
        table = soup.find_all('table')[1]
        headers = [header.text for header in table.find_all('th')]
        rows = []
        for row in table.find_all('tr')[1:]:
            cells = row.find_all('td')
            cells_text = [cell.text.strip() for cell in cells]
            rows.append(cells_text)

        columns = ['acct_name', 'this_year_amt', 'this_year_percent', 'last_year_amt', 'last_year_percent']
        # Create a DataFrame
        df_temp = pd.DataFrame(rows, columns=columns)
        df_select = df_temp.iloc[3:].copy()
        
        df_select['report_name'] = 'ProfitAndLose'
        df_select['company_id'] = otc[otc['stock_num'] == str(stock_number)].stock_num.values[0]
        df_select['company_name'] = otc[otc['stock_num'] == str(stock_number)].company_name.values[0]
        df_select['creation_date'] = datetime.now().strftime('%Y-%m-%d')
        df_select['seq'] = range(1, len(df_select) + 1)
            
        df_profitloss = pd.concat([df_profitloss, df_select], axis=0)
        
        print(f'get {stock_number}')
        
        # time.sleep(random.uniform(10, 35))
         
    except requests.RequestException as e:
        error_stock_list.append(stock_number)
        print(f'Failed to retrieve data for stock number {stock_number}: {e}')
    except ValueError as e:
        error_stock_list.append(stock_number)
        print(f'Error parsing data for stock number {stock_number}: {e}')
    except Exception as e:
        error_stock_list.append(stock_number)
        print(f'An unexpected error occurred for stock number {stock_number}: {e}')
# Out:
# get 1605

# %%
df_profitloss.head()
# Out:
#     acct_name this_year_amt this_year_percent last_year_amt last_year_percent  \
# 3      營業收入合計    40,549,837            100.00    50,713,578            100.00
# 4      營業成本合計    37,891,440             93.44    46,192,595             91.09
# 5    營業毛利（毛損）     2,658,397              6.56     4,520,983              8.91
# 6  營業毛利（毛損）淨額     2,658,397              6.56     4,520,983              8.91
# 7        營業費用
#
#      report_name company_id company_name creation_date  seq
# 3  ProfitAndLose       1605   華新麗華股份有限公司    2024-07-18    1
# 4  ProfitAndLose       1605   華新麗華股份有限公司    2024-07-18    2
# 5  ProfitAndLose       1605   華新麗華股份有限公司    2024-07-18    3
# 6  ProfitAndLose       1605   華新麗華股份有限公司    2024-07-18    4
# 7  ProfitAndLose       1605   華新麗華股份有限公司    2024-07-18    5

# %%
# df_profitloss.to_csv('profitloss_result.csv', index=False, encoding='utf-16')
df_profitloss_all = pd.read_csv('profitloss_result.csv', encoding='utf-16')

# %%
df_profitloss_all.report_name.unique()
# Out:
# array(['ProfitAndLose'], dtype=object)

# %%
df_profitloss_all_1605 = pd.concat([df_profitloss_all, df_profitloss], axis=0)

# %%
df_profitloss_all_1605.company_id.nunique()
# Out:
# 205

# %%
df_cash = pd.DataFrame()

# %%
# Cashflow
for stock_number in stock_list:
       
    # stock_number = '1231'
    year = 113
    season = 1
    url = CashFlowStatementURL

    form_data = {
        'encodeURIComponent':1,
        'step':1,
        'firstin':1,
        'off':1,
        'co_id':stock_number,
        'year': year,
        'season': season,
    }
    
    try:
        r = requests.post(url,form_data)
        soup = BeautifulSoup(r.text, 'html.parser')
        table = soup.find_all('table')[1]
        headers = [header.text for header in table.find_all('th')]
        rows = []
        for row in table.find_all('tr')[1:]:
            cells = row.find_all('td')
            cells_text = [cell.text.strip() for cell in cells]
            rows.append(cells_text)

        columns = ['acct_name', 'this_year_amt', 'last_year_amt']
        # Create a DataFrame
        df_temp = pd.DataFrame(rows, columns=columns)
        df_select = df_temp.iloc[3:].copy()
        
        df_select['report_name'] = 'CashFlowStatement'
        df_select['company_id'] = otc[otc['stock_num'] == str(stock_number)].stock_num.values[0]
        df_select['company_name'] = otc[otc['stock_num'] == str(stock_number)].company_name.values[0]
        df_select['creation_date'] = datetime.now().strftime('%Y-%m-%d')
        df_select['seq'] = range(1, len(df_select) + 1)
            
        df_cash = pd.concat([df_cash, df_select], axis=0)
        
        print(f'get {stock_number}')
        
        # time.sleep(random.uniform(10, 35))
         
    except requests.RequestException as e:
        error_stock_list.append(stock_number)
        print(f'Failed to retrieve data for stock number {stock_number}: {e}')
    except ValueError as e:
        error_stock_list.append(stock_number)
        print(f'Error parsing data for stock number {stock_number}: {e}')
    except Exception as e:
        error_stock_list.append(stock_number)
        print(f'An unexpected error occurred for stock number {stock_number}: {e}')
# Out:
# get 1605

# %%
df_cash.head()
# Out:
#         acct_name this_year_amt last_year_amt        report_name company_id  \
# 3   營業活動之現金流量－間接法                              CashFlowStatement       1605
# 4  繼續營業單位稅前淨利（淨損）       671,948     3,001,904  CashFlowStatement       1605
# 5      本期稅前淨利（淨損）       671,948     3,001,904  CashFlowStatement       1605
# 6            折舊費用     1,896,229     1,590,586  CashFlowStatement       1605
# 7            攤銷費用       328,756       257,232  CashFlowStatement       1605
#
#   company_name creation_date  seq
# 3   華新麗華股份有限公司    2024-07-18    1
# 4   華新麗華股份有限公司    2024-07-18    2
# 5   華新麗華股份有限公司    2024-07-18    3
# 6   華新麗華股份有限公司    2024-07-18    4
# 7   華新麗華股份有限公司    2024-07-18    5

# %%
# df_cash.to_csv('cash_result.csv', index=False, encoding='utf-16')
# df_cash_all = pd.read_csv('cash_result.csv', encoding='utf-16')

# %%
df_cash_all.report_name.unique()
# Out:
# array(['CashFlowStatement'], dtype=object)

# %%
df_cash_all.company_id.nunique()
# Out:
# 208

# %%
df_cash_all_1605 = pd.concat([df_cash_all, df_cash], axis=0)

# %%
df_cash_all.head()
# Out:
#         acct_name this_year_amt last_year_amt        report_name  company_id  \
# 0   營業活動之現金流量－間接法           NaN           NaN  CashFlowStatement     7568009
# 1  繼續營業單位稅前淨利（淨損）       351,086       315,487  CashFlowStatement     7568009
# 2      本期稅前淨利（淨損）       351,086       315,487  CashFlowStatement     7568009
# 3            折舊費用        47,185        44,550  CashFlowStatement     7568009
# 4            攤銷費用         1,006           890  CashFlowStatement     7568009
#
#   company_name creation_date  seq  stock
# 0   環球水泥股份有限公司    2024-07-16    1   1104
# 1   環球水泥股份有限公司    2024-07-16    2   1104
# 2   環球水泥股份有限公司    2024-07-16    3   1104
# 3   環球水泥股份有限公司    2024-07-16    4   1104
# 4   環球水泥股份有限公司    2024-07-16    5   1104

# %%
df_cash_all_1605
df_profitloss_all_1605
df_frc_balance

# %%
df_season_all_1605 = pd.concat([df_frc_2, df_profitloss, df_cash], axis=0)

# %%
df_season_all_1605['period_year'] = '113'
df_season_all_1605['season'] = '1'

# %%
df_season_all_1605 = df_season_all_1605.fillna(0)
df_season_all_1605
# Out:
#               acct_name this_year_amt this_year_percent last_year_amt  \
# 3                  流動資產
# 4               現金及約當現金    12,313,790              4.63     8,257,051
# 5   透過損益按公允價值衡量之金融資產－流動     1,339,835              0.50       150,209
# 6      按攤銷後成本衡量之金融資產－流動           737              0.00         1,509
# 7            避險之金融資產－流動         9,427              0.00        15,460
# ..                  ...           ...               ...           ...
# 70      匯率變動對現金及約當現金之影響     1,380,631                 0        39,246
# 71     本期現金及約當現金增加（減少）數    -4,033,222                 0   -11,181,708
# 72          期初現金及約當現金餘額    16,347,012                 0    19,438,759
# 73          期末現金及約當現金餘額    12,313,790                 0     8,257,051
# 74      資產負債表帳列之現金及約當現金    12,313,790                 0     8,257,051
#
#    last_year_percent        report_name company_id company_name creation_date  \
# 3                          BalanceSheet       1605   華新麗華股份有限公司    2024-07-18
# 4               3.23       BalanceSheet       1605   華新麗華股份有限公司    2024-07-18
# 5               0.06       BalanceSheet       1605   華新麗華股份有限公司    2024-07-18
# 6               0.00       BalanceSheet       1605   華新麗華股份有限公司    2024-07-18
# 7               0.01       BalanceSheet       1605   華新麗華股份有限公司    2024-07-18
# ..               ...                ...        ...          ...           ...
# 70                 0  CashFlowStatement       1605   華新麗華股份有限公司    2024-07-18
# 71                 0  CashFlowStatement       1605   華新麗華股份有限公司    2024-07-18
# 72                 0  CashFlowStatement       1605   華新麗華股份有限公司    2024-07-18
# 73                 0  CashFlowStatement       1605   華新麗華股份有限公司    2024-07-18
# 74                 0  CashFlowStatement       1605   華新麗華股份有限公司    2024-07-18
#
#     seq period_year season
# 3     1         113      1
# 4     2         113      1
# 5     3         113      1
# 6     4         113      1
# 7     5         113      1
# ..  ...         ...    ...
# 70   68         113      1
# 71   69         113      1
# 72   70         113      1
# 73   71         113      1
# 74   72         113      1
#
# [185 rows x 12 columns]

# %%
sql_agent.write_table(data=df_season_all_1605, table_name='mops_season_report_copy', index=False, if_exists='append', data_type=None)

# %%
df_test = fr.head()

# %%
# read balacne
df_balance = pd.read_csv('balance_result.csv')
# read profitloss
df_profitloss = pd.read_csv('profitloss_result.csv', encoding='utf-16')
# read cash
df_cash = pd.read_csv('cash_result.csv', encoding='utf-16')

# %%
df_balance.head()
# Out:
#                  acct_name this_year_amt  this_year_percent last_year_amt  \
# 0                     流動資產           NaN                NaN           NaN
# 1                  現金及約當現金     1,136,975               3.98       840,325
# 2      透過損益按公允價值衡量之金融資產－流動        14,619               0.05        57,577
# 3  透過其他綜合損益按公允價值衡量之金融資產－流動     2,869,282              10.04     2,392,367
# 4         按攤銷後成本衡量之金融資產－流動       131,334               0.46       102,367
#
#    last_year_percent   report_name  company_id company_name creation_date  \
# 0                NaN  BalanceSheet     7568009   環球水泥股份有限公司    2024-07-13
# 1               2.99  BalanceSheet     7568009   環球水泥股份有限公司    2024-07-13
# 2               0.20  BalanceSheet     7568009   環球水泥股份有限公司    2024-07-13
# 3               8.50  BalanceSheet     7568009   環球水泥股份有限公司    2024-07-13
# 4               0.36  BalanceSheet     7568009   環球水泥股份有限公司    2024-07-13
#
#    seq  stock
# 0    1   1104
# 1    2   1104
# 2    3   1104
# 3    4   1104
# 4    5   1104

# %%
df_profitloss.head()
# Out:
#     acct_name this_year_amt this_year_percent last_year_amt last_year_percent  \
# 0      營業收入合計     1,908,572            100.00     1,835,530            100.00
# 1      營業成本合計     1,525,149             79.91     1,490,975             81.23
# 2    營業毛利（毛損）       383,423             20.09       344,555             18.77
# 3  營業毛利（毛損）淨額       383,423             20.09       344,555             18.77
# 4        營業費用           NaN               NaN           NaN               NaN
#
#      report_name  company_id company_name creation_date  seq  stock
# 0  ProfitAndLose     7568009   環球水泥股份有限公司    2024-07-16    1   1104
# 1  ProfitAndLose     7568009   環球水泥股份有限公司    2024-07-16    2   1104
# 2  ProfitAndLose     7568009   環球水泥股份有限公司    2024-07-16    3   1104
# 3  ProfitAndLose     7568009   環球水泥股份有限公司    2024-07-16    4   1104
# 4  ProfitAndLose     7568009   環球水泥股份有限公司    2024-07-16    5   1104

# %%
df_all = pd.concat([df_balance, df_profitloss, df_cash], axis=0).fillna(0)

# %%
df_all['period_year'] = '113'
df_all['season'] = '2'
df_all['company_id'] = df_all['stock']
df_all = df_all.drop(['stock'], axis=1)

# %%
df_all.head()
# Out:
#                  acct_name this_year_amt this_year_percent last_year_amt  \
# 0                     流動資產             0                 0             0
# 1                  現金及約當現金     1,136,975              3.98       840,325
# 2      透過損益按公允價值衡量之金融資產－流動        14,619              0.05        57,577
# 3  透過其他綜合損益按公允價值衡量之金融資產－流動     2,869,282             10.04     2,392,367
# 4         按攤銷後成本衡量之金融資產－流動       131,334              0.46       102,367
#
#   last_year_percent   report_name  company_id company_name creation_date  seq  \
# 0                 0  BalanceSheet        1104   環球水泥股份有限公司    2024-07-13    1
# 1              2.99  BalanceSheet        1104   環球水泥股份有限公司    2024-07-13    2
# 2               0.2  BalanceSheet        1104   環球水泥股份有限公司    2024-07-13    3
# 3               8.5  BalanceSheet        1104   環球水泥股份有限公司    2024-07-13    4
# 4              0.36  BalanceSheet        1104   環球水泥股份有限公司    2024-07-13    5
#
#   period_year season
# 0         113      2
# 1         113      2
# 2         113      2
# 3         113      2
# 4         113      2

# %%
# Remove commas and convert to numeric, forcing errors to NaN
df_all['this_year_amt'] = pd.to_numeric(df_all['this_year_amt'].str.replace(',', ''), errors='coerce').fillna(0).astype(int)
df_all['last_year_amt'] = pd.to_numeric(df_all['last_year_amt'].str.replace(',', ''), errors='coerce').fillna(0).astype(int)

# %%
df_test
# Out:
#     report_name company_id company_name  period_year  season  \
# 0  BalanceSheet       1101           台泥          112       1
# 1  BalanceSheet       1101           台泥          112       1
# 2  BalanceSheet       1101           台泥          112       1
# 3  BalanceSheet       1101           台泥          112       1
# 4  BalanceSheet       1101           台泥          112       1
#
#                  acct_name  this_year_amt  this_year_percent  last_year_amt  \
# 0                     流動資產            0.0               0.00            0.0
# 1                  現金及約當現金     70957209.0              15.37     88842494.0
# 2      透過損益按公允價值衡量之金融資產－流動       648145.0               0.14       611802.0
# 3  透過其他綜合損益按公允價值衡量之金融資產－流動      6377062.0               1.38      5934753.0
# 4         按攤銷後成本衡量之金融資產－流動     30795636.0               6.67     20954299.0
#
#    last_year_percent       creation_date  seq
# 0               0.00 2024-04-10 13:45:47    1
# 1              19.28 2024-04-10 13:45:47    2
# 2               0.13 2024-04-10 13:45:47    3
# 3               1.29 2024-04-10 13:45:47    4
# 4               4.55 2024-04-10 13:45:47    5

# %%
pd.concat([df_test, df_all.head()], axis=0)
# Out:
#     report_name company_id company_name period_year season  \
# 0  BalanceSheet       1101           台泥         112      1
# 1  BalanceSheet       1101           台泥         112      1
# 2  BalanceSheet       1101           台泥         112      1
# 3  BalanceSheet       1101           台泥         112      1
# 4  BalanceSheet       1101           台泥         112      1
# 0  BalanceSheet       1104   環球水泥股份有限公司         113      2
# 1  BalanceSheet       1104   環球水泥股份有限公司         113      2
# 2  BalanceSheet       1104   環球水泥股份有限公司         113      2
# 3  BalanceSheet       1104   環球水泥股份有限公司         113      2
# 4  BalanceSheet       1104   環球水泥股份有限公司         113      2
#
#                  acct_name this_year_amt this_year_percent last_year_amt  \
# 0                     流動資產           0.0               0.0           0.0
# 1                  現金及約當現金    70957209.0             15.37    88842494.0
# 2      透過損益按公允價值衡量之金融資產－流動      648145.0              0.14      611802.0
# 3  透過其他綜合損益按公允價值衡量之金融資產－流動     6377062.0              1.38     5934753.0
# 4         按攤銷後成本衡量之金融資產－流動    30795636.0              6.67    20954299.0
# 0                     流動資產           0.0               0.0           0.0
# 1                  現金及約當現金     1,136,975              3.98       840,325
# 2      透過損益按公允價值衡量之金融資產－流動        14,619              0.05        57,577
# 3  透過其他綜合損益按公允價值衡量之金融資產－流動     2,869,282             10.04     2,392,367
# 4         按攤銷後成本衡量之金融資產－流動       131,334              0.46       102,367
#
#   last_year_percent        creation_date  seq
# 0               0.0  2024-04-10 13:45:47    1
# 1             19.28  2024-04-10 13:45:47    2
# 2              0.13  2024-04-10 13:45:47    3
# 3              1.29  2024-04-10 13:45:47    4
# 4              4.55  2024-04-10 13:45:47    5
# 0               0.0           2024-07-13    1
# 1              2.99           2024-07-13    2
# 2               0.2           2024-07-13    3
# 3               8.5           2024-07-13    4
# 4              0.36           2024-07-13    5

# %%
from sqlalchemy.types import VARCHAR, INTEGER, DECIMAL, DATETIME

data_type = {
    "report_name": VARCHAR(50),
    "company_id": VARCHAR(4),
    "company_name": VARCHAR(50),
    "period_year": INTEGER(),
    "season": INTEGER(),
    "acct_name": VARCHAR(100),
    "this_year_amt": INTEGER(),
    "this_year_percent": DECIMAL(20, 6),
    "last_year_amt": INTEGER(),
    "last_year_percent": DECIMAL(20, 6),
    "creation_date": DATETIME(),
    "seq": INTEGER()
}

# %%
query = """
select *
from mops_season_report_copy
"""

fr_copy = sql_agent.read_table(query=query)
fr_copy
# Out:
# Empty DataFrame
# Columns: [acct_name, this_year_amt, this_year_percent, last_year_amt, last_year_percent, report_name, company_id, company_name, creation_date, seq, period_year, season]
# Index: []

# %%
df_final = pd.concat([fr_copy, df_all], axis=0)

# %%
df_final.dtypes
# Out:
# report_name          object
# company_id           object
# company_name         object
# period_year          object
# season               object
# acct_name            object
# this_year_amt         int64
# this_year_percent    object
# last_year_amt         int64
# last_year_percent    object
# creation_date        object
# seq                   int64
# dtype: object

# %%
def format_with_commas(x):
    return f"{x:,}"

df_final['this_year_percent'] = df_final['this_year_percent'].apply(format_with_commas)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[155], line 4
#       1 def format_with_commas(x):
#       2     return f"{x:,}"
# ----> 4 df_final['this_year_percent'] = df_final['this_year_percent'].apply(format_with_commas)
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[155], line 2, in format_with_commas(x)
#       1 def format_with_commas(x):
# ----> 2     return f"{x:,}"
#
# ValueError: Cannot specify ',' with 's'.

# %%
df_final['this_year_amt'] = df_final['this_year_amt'].astype(str)
df_final['last_year_amt'] = df_final['last_year_amt'].astype(str)

# %%
df_select_1 = df_final[df_final['period_year'] == '113' &]

# %%
sql_agent.write_table(df_all, table_name='mops_season_report', if_exists='append', index=None, data_type=None)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\sqlalchemy\engine\base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:170, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     169 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 170     rowcount = cursor.executemany(statement, parameters)
#     171     if context is not None:
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pymysql\cursors.py:182, in Cursor.executemany(self, query, args)
#     181     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 182     return self._do_execute_many(
#     183         q_prefix,
#     184         q_values,
#     185         q_postfix,
#     186         args,
#     187         self.max_stmt_length,
#     188         self._get_db().encoding,
#     189     )
#     191 self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pymysql\cursors.py:215, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     214 if len(sql) + len(v) + len(postfix) + 1 > max_stmt_length:
# --> 215     rows += self.execute(sql + postfix)
#     216     sql = bytearray(prefix)
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1198 try:
# -> 1199     first_packet = self.connection._read_packet()
#    1201     if first_packet.is_ok_packet():
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# DataError: (1366, "Incorrect decimal value: '1,048.80' for column 'last_year_percent' at row 4012")
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# Cell In[190], line 1
# ----> 1 sql_agent.write_table(df_all, table_name='mops_season_report', if_exists='append', index=None, data_type=None)
#
# File c:\Users\sean.chang\yfy\creative_corner\financial-report-crawler\utils.py:42, in MySQLAgent.write_table(self, data, table_name, if_exists, index, data_type)
#      40 def write_table(self, data, table_name, if_exists, index, data_type):
# ---> 42     data.to_sql(name=table_name, con=self.engine,
#      43                 if_exists=if_exists, index=index, dtype=data_type)
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pandas\core\generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
#    2891
#    (...)
#    3083 [(1,), (None,), (2,)]
#    3084 """  # noqa: E501
#    3085 from pandas.io import sql
# -> 3087 return sql.to_sql(
#    3088     self,
#    3089     name,
#    3090     con,
#    3091     schema=schema,
#    3092     if_exists=if_exists,
#    3093     index=index,
#    3094     index_label=index_label,
#    3095     chunksize=chunksize,
#    3096     dtype=dtype,
#    3097     method=method,
#    3098 )
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pandas\io\sql.py:842, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
#     841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#     845         if_exists=if_exists,
#     846         index=index,
#     847         index_label=index_label,
#     848         schema=schema,
#     849         chunksize=chunksize,
#     850         dtype=dtype,
#     851         method=method,
#     852         engine=engine,
#     853         **engine_kwargs,
#     854     )
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pandas\io\sql.py:2018, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2006 sql_engine = get_engine(engine)
#    2008 table = self.prep_table(
#    2009     frame=frame,
#    2010     name=name,
#    (...)
#    2015     dtype=dtype,
#    2016 )
# -> 2018 total_inserted = sql_engine.insert_records(
#    2019     table=table,
#    2020     con=self.con,
#    2021     frame=frame,
#    2022     name=name,
#    2023     index=index,
#    2024     schema=schema,
#    2025     chunksize=chunksize,
#    2026     method=method,
#    2027     **engine_kwargs,
#    2028 )
#    2030 self.check_case_sensitive(name=name, schema=schema)
#    2031 return total_inserted
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pandas\io\sql.py:1567, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1565 if re.search(msg, err_text):
#    1566     raise ValueError("inf cannot be used with MySQL") from err
# -> 1567 raise err
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pandas\io\sql.py:1558, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1555 from sqlalchemy import exc
#    1557 try:
# -> 1558     return table.insert(chunksize=chunksize, method=method)
#    1559 except exc.StatementError as err:
#    1560     # GH34431
#    1561     # https://stackoverflow.com/a/67358288/6067848
#    1562     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1563     )|inf can not be used with MySQL"""
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pandas\io\sql.py:1119, in SQLTable.insert(self, chunksize, method)
#    1116     break
#    1118 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1119 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1120 # GH 46891
#    1121 if num_inserted is not None:
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pandas\io\sql.py:1010, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     998 """
#     999 Execute SQL statement inserting data
#    1000
#    (...)
#    1007    Each item contains a list of values to be inserted
#    1008 """
#    1009 data = [dict(zip(keys, row)) for row in data_iter]
# -> 1010 result = conn.execute(self.table.insert(), data)
#    1011 return result.rowcount
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\sqlalchemy\engine\base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1416     raise exc.ObjectNotExecutableError(statement) from err
#    1417 else:
# -> 1418     return meth(
#    1419         self,
#    1420         distilled_parameters,
#    1421         execution_options or NO_OPTIONS,
#    1422     )
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\sqlalchemy\sql\elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\sqlalchemy\engine\base.py:1640, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1628 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1629     "compiled_cache", self.engine._compiled_cache
#    1630 )
#    1632 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1633     dialect=dialect,
#    1634     compiled_cache=compiled_cache,
#    (...)
#    1638     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1639 )
# -> 1640 ret = self._execute_context(
#    1641     dialect,
#    1642     dialect.execution_ctx_cls._init_compiled,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     execution_options,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     elem,
#    1649     extracted_params,
#    1650     cache_hit=cache_hit,
#    1651 )
#    1652 if has_events:
#    1653     self.dispatch.after_execute(
#    1654         self,
#    1655         elem,
#    (...)
#    1659         ret,
#    1660     )
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\sqlalchemy\engine\base.py:2353, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2351 elif should_wrap:
#    2352     assert sqlalchemy_exception is not None
# -> 2353     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2354 else:
#    2355     assert exc_info[1] is not None
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\sqlalchemy\engine\base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1934                 break
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#    1943     if self.dialect._has_events:
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:170, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     169 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 170     rowcount = cursor.executemany(statement, parameters)
#     171     if context is not None:
#     172         context._rowcount = rowcount
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pymysql\cursors.py:182, in Cursor.executemany(self, query, args)
#     180     q_postfix = m.group(3) or ""
#     181     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 182     return self._do_execute_many(
#     183         q_prefix,
#     184         q_values,
#     185         q_postfix,
#     186         args,
#     187         self.max_stmt_length,
#     188         self._get_db().encoding,
#     189     )
#     191 self.rowcount = sum(self.execute(query, arg) for arg in args)
#     192 return self.rowcount
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pymysql\cursors.py:215, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     213     v = v.encode(encoding, "surrogateescape")
#     214 if len(sql) + len(v) + len(postfix) + 1 > max_stmt_length:
# --> 215     rows += self.execute(sql + postfix)
#     216     sql = bytearray(prefix)
#     217 else:
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pymysql\connections.py:563, in Connection.query(self, sql, unbuffered)
#     561     sql = sql.encode(self.encoding, "surrogateescape")
#     562 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pymysql\connections.py:825, in Connection._read_query_result(self, unbuffered)
#     823 else:
#     824     result = MySQLResult(self)
# --> 825     result.read()
#     826 self._result = result
#     827 if result.server_status is not None:
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pymysql\connections.py:1199, in MySQLResult.read(self)
#    1197 def read(self):
#    1198     try:
# -> 1199         first_packet = self.connection._read_packet()
#    1201         if first_packet.is_ok_packet():
#    1202             self._read_ok_packet(first_packet)
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pymysql\connections.py:775, in Connection._read_packet(self, packet_type)
#     773     if self._result is not None and self._result.unbuffered_active is True:
#     774         self._result.unbuffered_active = False
# --> 775     packet.raise_for_error()
#     776 return packet
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File c:\Users\sean.chang\AppData\Local\anaconda3\envs\frc\lib\site-packages\pymysql\err.py:150, in raise_mysql_exception(data)
#     148 if errorclass is None:
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# DataError: (pymysql.err.DataError) (1366, "Incorrect decimal value: '1,048.80' for column 'last_year_percent' at row 4012")
# [SQL: INSERT INTO mops_season_report (acct_name, this_year_amt, this_year_percent, last_year_amt, last_year_percent, report_name, company_id, company_name, creation_date, seq, period_year, season) VALUES (%(acct_name)s, %(this_year_amt)s, %(this_year_percent)s, %(last_year_amt)s, %(last_year_percent)s, %(report_name)s, %(company_id)s, %(company_name)s, %(creation_date)s, %(seq)s, %(period_year)s, %(season)s)]
# [parameters: [{'acct_name': '流動資產', 'this_year_amt': 0, 'this_year_percent': 0, 'last_year_amt': 0, 'last_year_percent': 0, 'report_name': 'BalanceSheet', 'company_id': 1104, 'company_name': '環球水泥股份有限公司', 'creation_date': '2024-07-13', 'seq': 1, 'period_year': '113', 'season': '2'}, {'acct_name': '現金及約當現金', 'this_year_amt': 1136975, 'this_year_percent': 3.98, 'last_year_amt': 840325, 'last_year_percent': 2.99, 'report_name': 'BalanceSheet', 'company_id': 1104, 'company_name': '環球水泥股份有限公司', 'creation_date': '2024-07-13', 'seq': 2, 'period_year': '113', 'season': '2'}, {'acct_name': '透過損益按公允價值衡量之金融資產－流動', 'this_year_amt': 14619, 'this_year_percent': 0.05, 'last_year_amt': 57577, 'last_year_percent': 0.2, 'report_name': 'BalanceSheet', 'company_id': 1104, 'company_name': '環球水泥股份有限公司', 'creation_date': '2024-07-13', 'seq': 3, 'period_year': '113', 'season': '2'}, {'acct_name': '透過其他綜合損益按公允價值衡量之金融資產－流動', 'this_year_amt': 2869282, 'this_year_percent': 10.04, 'last_year_amt': 2392367, 'last_year_percent': 8.5, 'report_name': 'BalanceSheet', 'company_id': 1104, 'company_name': '環球水泥股份有限公司', 'creation_date': '2024-07-13', 'seq': 4, 'period_year': '113', 'season': '2'}, {'acct_name': '按攤銷後成本衡量之金融資產－流動', 'this_year_amt': 131334, 'this_year_percent': 0.46, 'last_year_amt': 102367, 'last_year_percent': 0.36, 'report_name': 'BalanceSheet', 'company_id': 1104, 'company_name': '環球水泥股份有限公司', 'creation_date': '2024-07-13', 'seq': 5, 'period_year': '113', 'season': '2'}, {'acct_name': '應收票據淨額', 'this_year_amt': 536726, 'this_year_percent': 1.88, 'last_year_amt': 457621, 'last_year_percent': 1.63, 'report_name': 'BalanceSheet', 'company_id': 1104, 'company_name': '環球水泥股份有限公司', 'creation_date': '2024-07-13', 'seq': 6, 'period_year': '113', 'season': '2'}, {'acct_name': '應收帳款淨額', 'this_year_amt': 1401711, 'this_year_percent': 4.91, 'last_year_amt': 1397506, 'last_year_percent': 4.97, 'report_name': 'BalanceSheet', 'company_id': 1104, 'company_name': '環球水泥股份有限公司', 'creation_date': '2024-07-13', 'seq': 7, 'period_year': '113', 'season': '2'}, {'acct_name': '應收帳款－關係人淨額', 'this_year_amt': 38814, 'this_year_percent': 0.14, 'last_year_amt': 35932, 'last_year_percent': 0.13, 'report_name': 'BalanceSheet', 'company_id': 1104, 'company_name': '環球水泥股份有限公司', 'creation_date': '2024-07-13', 'seq': 8, 'period_year': '113', 'season': '2'}  ... displaying 10 of 32952 total bound parameter sets ...  {'acct_name': '資產負債表帳列之現金及約當現金', 'this_year_amt': 1910157, 'this_year_percent': 0, 'last_year_amt': 2163687, 'last_year_percent': 0, 'report_name': 'CashFlowStatement', 'company_id': 9944, 'company_name': '新麗企業股份有限公司', 'creation_date': '2024-07-16', 'seq': 63, 'period_year': '113', 'season': '2'}, {'acct_name': '分類至待出售（非流動）資產（或處分群組）之現金及約當現金', 'this_year_amt': 480633, 'this_year_percent': 0, 'last_year_amt': 0, 'last_year_percent': 0, 'report_name': 'CashFlowStatement', 'company_id': 9944, 'company_name': '新麗企業股份有限公司', 'creation_date': '2024-07-16', 'seq': 64, 'period_year': '113', 'season': '2'}]]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)

# %%
df_all.iloc[6190]
# Out:
# acct_name                    流動資產合計
# this_year_amt            2452767394
# this_year_percent             42.38
# last_year_amt            1995727521
# last_year_percent             39.55
# report_name            BalanceSheet
# company_id                     2330
# company_name         台灣積體電路製造股份有限公司
# creation_date            2024-07-13
# seq                              12
# period_year                     113
# season                            2
# Name: 6190, dtype: object
